# %%
import os
import cv2
import face_recognition

# %%
import os
import cv2
import face_recognition
imgs_list=["yumna.jpg","sejal.jpg","faysal.png","soad.jpg","nour.jpg","Basma.jpg","fayrouz.jpg"]
encodings=[]
names=[]
for i in imgs_list:
    name=os.path.splitext(i)[0]
    i = cv2.imread(i)
    rgb_img = cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
    enc=face_recognition.face_encodings(rgb_img)[0]
    encodings.append(enc)
    names.append(name)
#print(encodings[0])

# %%
import numpy as np
def comparison(input_image):
    name="Unknown person"
    img2 = cv2.imread(input_image)
    rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    face_locations = face_recognition.face_locations(rgb_img2)
    y1, x2, y2, x1 = face_locations[0][0], face_locations[0][1], face_locations[0][2], face_locations[0][3]
    
    

    
    img_encoding2 = face_recognition.face_encodings(rgb_img2)[0]
    #print(img_encoding2)
    j=0
    for i in encodings:
         result=face_recognition.compare_faces([i],img_encoding2)
         #print(result)
         if result==[True]:
             name=names[j]
             break
         j+=1
    cv2.putText(rgb_img2, name,(x1, y1 - 10), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 200), 2)
    cv2.rectangle(rgb_img2, (x1, y1), (x2, y2), (0, 0, 200), 4)
    cv2.imshow("image", rgb_img2)
    cv2.waitKey(0)
    return name

print(comparison("n.jpg"))
# Out:
# nour

# %%
def comparison(input_image):
    name="Unknown person"
    #img2 = cv2.imread(input_image)
    rgb_img2 = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
    face_locations = face_recognition.face_locations(rgb_img2)
    if face_locations:
        y1, x2, y2, x1 = face_locations[0][0], face_locations[0][1], face_locations[0][2], face_locations[0][3]
    
    

    
        img_encoding2 = face_recognition.face_encodings(rgb_img2)[0]
    #print(img_encoding2)
        j=0
        for i in encodings:
             result=face_recognition.compare_faces([i],img_encoding2)
         #print(result)
             if result==[True]:
                 name=names[j]
                 break
             j+=1
        cv2.putText(rgb_img2, name,(x1, y1 - 10), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 200), 2)
        cv2.rectangle(rgb_img2, (x1, y1), (x2, y2), (0, 0, 200), 4)
        cv2.imshow("image", rgb_img2)
        k=cv2.waitKey(1)
        if k==27:
            return "stop"
        
    """else:
        #print("No faces in the image")
        continue"""

# %%
cap = cv2.VideoCapture(0)

cap.set(3,300)
cap.set(4,300)
while True:
    ret, frame = cap.read()
    n=comparison(frame)
    if n=="stop":
        break
cap.release()
    
    # Detect Faces
